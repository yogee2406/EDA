# %% [markdown]
# <a href="https://colab.research.google.com/gist/yogee2406/44824214dafc45628e3bafd2b606fe9b/eda-imdb-yogeeta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# You missed this part  this is mandatory  for using  pandas profiling  always import this on the top

# %%
# !pip install -q datascience                                         # Package that is required by pandas profiling
# !pip install -q pandas-profiling                                    # Library to generate basic statistics about data
# To install more libraries insert your code here..
# Out:
#      |████████████████████████████████| 69 kB 3.4 MB/s
# ...

# %%
# !pip install -q --upgrade pandas-profiling
# Out:
#      |████████████████████████████████| 261 kB 5.4 MB/s
#      |████████████████████████████████| 303 kB 48.5 MB/s
#      |████████████████████████████████| 3.1 MB 45.5 MB/s
#      |████████████████████████████████| 63 kB 1.6 MB/s
#      |████████████████████████████████| 102 kB 11.6 MB/s
#      |████████████████████████████████| 675 kB 63.9 MB/s
#      |████████████████████████████████| 596 kB 55.7 MB/s
#      |████████████████████████████████| 10.9 MB 42.9 MB/s
#      |████████████████████████████████| 812 kB 48.1 MB/s
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
#-------------------------------------------------------------------------------------------------------------------------------
import pandas as pd                                                 # Importing package pandas (For Panel Data Analysis)
from pandas_profiling import ProfileReport                          # Import Pandas Profiling (To generate Univariate Analysis)
#-------------------------------------------------------------------------------------------------------------------------------
import numpy as np                  
import missingno as msno                                # Importing package numpys (For Numerical Python)
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                     # Importing pyplot interface to use matplotlib
import seaborn as sns                                               # Importing seaborn library for interactive visualization
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
import scipy as sp                                                  # Importing library for scientific calculations
#-------------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
links = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/1000%20movies%20data.csv')
links.head(10)
# Out:
#    Rank                    Title  ... Revenue (Millions) Metascore
# 0     1  Guardians of the Galaxy  ...             333.13      76.0
# 1     2               Prometheus  ...             126.46      65.0
# 2     3                    Split  ...             138.12      62.0
# 3     4                     Sing  ...             270.32      59.0
# 4     5            Suicide Squad  ...             325.02      40.0
# 5     6           The Great Wall  ...              45.13      42.0
# 6     7               La La Land  ...             151.06      93.0
# 7     8                 Mindhorn  ...                NaN      71.0
# 8     9       The Lost City of Z  ...               8.01      78.0
# 9    10               Passengers  ...             100.01      41.0
#
# [10 rows x 12 columns]

# %% [markdown]
# **Maximum of Some Columns**

# %%
max(links.Votes)
# Out:
# 1791916

# %%
#url=pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/1000%20movies%20data.csv')

# %%
type(links)
#len(links)
# Out:
# pandas.core.frame.DataFrame

# %%
links.head(2)
# Out:
#    Rank                    Title  ... Revenue (Millions) Metascore
# 0     1  Guardians of the Galaxy  ...             333.13      76.0
# 1     2               Prometheus  ...             126.46      65.0
#
# [2 rows x 12 columns]

# %%
links.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
links.head(3)
# Out:
#    Rank                    Title  ... Revenue (Millions) Metascore
# 0     1  Guardians of the Galaxy  ...             333.13      76.0
# 1     2               Prometheus  ...             126.46      65.0
# 2     3                    Split  ...             138.12      62.0
#
# [3 rows x 12 columns]

# %% [markdown]
# Method chaining

# %%
links.mean()
# Out:
# Rank                     500.500000
# Year                    2012.783000
# Runtime (Minutes)        113.172000
# Rating                     6.723200
# Votes                 169808.255000
# Revenue (Millions)        82.956376
# Metascore                 58.985043
# dtype: float64

# %%
links.mean().sort_values().head(2)
# Out:
# Rating        6.723200
# Metascore    58.985043
# dtype: float64

# %%
links.describe()
# Out:
#               Rank         Year  ...  Revenue (Millions)   Metascore
# count  1000.000000  1000.000000  ...          872.000000  936.000000
# mean    500.500000  2012.783000  ...           82.956376   58.985043
# std     288.819436     3.205962  ...          103.253540   17.194757
# min       1.000000  2006.000000  ...            0.000000   11.000000
# 25%     250.750000  2010.000000  ...           13.270000   47.000000
# 50%     500.500000  2014.000000  ...           47.985000   59.500000
# 75%     750.250000  2016.000000  ...          113.715000   72.000000
# max    1000.000000  2016.000000  ...          936.630000  100.000000
#
# [8 rows x 7 columns]

# %% [markdown]
# **Observation**
#
#
# 1.   The average rating of movie is 6.7 and of runtime of 66 mins
# 2.   Maximum revenue earned was in year 2016  by the movies is 936.630 Millions
# 3.   Minimum revenue earned is 0.0 and recevied  6.1 votes with Metascore rating of 11 which need to be investigated
# 4.   Approx  25 % Movies released during 2014-16 have earned revenue from 47 to 113 millions revenues
# 5.   Average  metascore of 58 with 82 million revenue earned in 2021
# 6.   Average runtime of the movies is 113 minutes

# %% [markdown]
# **Data Information**
#
# In this section we will see the information about the types of features.

# %%
links.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# **Observations**
# 1.   We have 4 numerical (int64)  and 3 float columns in the dataset

# %% [markdown]
# 5**. Data Pre-Profiling**
#
# 1.   This section is emphasised on getting a report about the data.
# 2.   You need to perform pandas profiling and get some observations out of it...

# %%
profile = ProfileReport(df =links)
profile.to_file(output_file = 'Pre Profiling Report.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# **Observations**
#
# 1. We have  7 numerical & 5 categorical features
# 2.  We have high missing values in Revenues & metascore columns
# 3.  Title and  has high cardinality distinct values
# 4.  Description & Rank  has unique values
# 5.  No Duplicates row  found in the dataset
# 6.   Revenue (Millions) is highly correlated with Votes
# 7.   Votes is highly correlated with Year and 2 other fields
# 8.   Description has a high cardinality: 1000 distinct values

# %% [markdown]
# **6. Data Pre-Processing**
# ---------------------------------------------------------------------------
# *   This section is emphasised on performing data manipulation over unstructured data for further processing and analysis.
#
# *   To modify unstructured data to strucuted data you need to verify and manipulate the integrity of the data by:
#
#
#     *   Handling missing data,
#     *   Handling redundant data,
#     *   Handling inconsistent data,
#     *   Handling outliers,
#     *   Handling typos

# %% [markdown]
# **Data Cleaning**
# 1.   In this section, we will perform the cleaning operations over the features using information from the previous section.
# 2.   We will simply drop the rows that contain missing values.

# %%
new_links = links.dropna(axis =0 , how = 'any')
print("Old data frame length:", len(links))
print("New data frame length:", len(new_links)) 
print("Number of rows with at least 1 NA value: ",
      (len(links)-len(new_links)))
new_links.head()
# Out:
# Old data frame length: 1000
# New data frame length: 838
# Number of rows with at least 1 NA value:  162
#    Rank                    Title  ... Revenue (Millions) Metascore
# 0     1  Guardians of the Galaxy  ...             333.13      76.0
# 1     2               Prometheus  ...             126.46      65.0
# 2     3                    Split  ...             138.12      62.0
# 3     4                     Sing  ...             270.32      59.0
# 4     5            Suicide Squad  ...             325.02      40.0
#
# [5 rows x 12 columns]

# %% [markdown]
# **7. Data Post-Profiling**
# ---------------------------------------------------------------------------
# 1.   This section is emphasised on getting a report about the data after the data manipulation.
# 2.   You may end up observing some new changes, so keep it under check and make right observations.

# %%
profile = ProfileReport(df = new_links)
profile.to_file(output_file = 'Post Profiling Report.html')
print('Accomplished!')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Accomplished!

# %% [markdown]
# **Observations**
# 1.   No missing values in the dataset
# 2.   Rank is highly correlated with df_index
# 3.   Year is highly correlated with Votes
# 4.   df_index has unique values

# %% [markdown]
# **8. Exploratory Data Analysis**
# ---------------------------------------------------------------------------
# *   This section is emphasised on asking the right questions and perform analysis using the data.
# *   Note that there is no limit how deep you can go, but make sure not to get distracted from right track.

# %% [markdown]
# To Obtain the  unique values across the dataset for all columns and max & minimum ratings

# %%
df = new_links.nunique (axis=0, dropna=True) 
print("No.of.unique values in each column :\n",df) 
column = new_links["Rating"] 
max_value = column.max()
min_value = column.min() 
print("Max Value", max_value)
print("Min Value " ,min_value)
# Out:
# No.of.unique values in each column :
#  Rank                  838
# Title                 837
# Genre                 189
# Description           838
# Director              524
# Actors                834
# Year                   11
# Runtime (Minutes)      90
# Rating                 50
# Votes                 837
# Revenue (Millions)    789
# Metascore              82
# dtype: int64
# Max Value 9.0
# Min Value  1.9

# %% [markdown]
# **Observation**
# 1.   Maximum rating is 9.0 and minimum rating is 1.9 overall
# 2.   List item

# %% [markdown]
# #We will groupby with genre  and title  in one dataframe

# %%
dk = new_links.groupby(['Genre', 'Title'])
dk.first()
# Out:
#                                                     Rank  ... Metascore
# Genre                      Title                          ...
# Action                     Kickboxer: Vengeance      581  ...      37.0
# Action,Adventure           Hercules                  285  ...      47.0
#                            Spider-Man 3              345  ...      59.0
#                            The Amazing Spider-Man    369  ...      66.0
# Action,Adventure,Biography In the Heart of the Sea   559  ...      47.0
# ...                                                  ...  ...       ...
# Mystery,Thriller           The Ghost Writer          541  ...      77.0
#                            The Gift                  557  ...      77.0
# Sci-Fi                     2307: Winter's Dream      617  ...      53.0
# Sci-Fi,Thriller            The Happening             513  ...      34.0
# Thriller                   The Guest                 730  ...      76.0
#
# [838 rows x 10 columns]

# %%
def plotBarChart(data=None, column=None, xlabel=None):
  """Creates bar chart depicting frequency distribution of categorical features."""

  # Create a figure size of 15 X 7 inches.
  figure = plt.figure(figsize=[15, 7])

  # Using pandas .plot.bar() function for barplot
  data[column].value_counts().plot.bar()

  # Changning x-ticks to 0 degree
  plt.xticks(rotation=0)

  # Set x, y labels of size 14 and title label of size 16.
  plt.xlabel(xlabel=xlabel, size=14)
  plt.ylabel(ylabel='Frequency', size=14)
  plt.title(label='Frequency Distribution of '+column, size=16)

  # Display the output
  plt.show()

# %%
plotBarChart(data=new_links, column='Rating', xlabel='Rating')

# %% [markdown]
# **Observations**
#
# 1.Frequency and Rating are positively correlated.
# 2.As the number of ratings increases, the frequency distribution also shows a peak as is the case in the above barchart where the rating of 7.0 shows a frequency distribution of over 40.

# %%
def plotScatterChart(data=None, xaxis=None, yaxis=None,):
  """Creates scatter chart of two numerical features."""

  # Using pandas .plot.scatter() function
  data.plot.scatter(x=xaxis, y=yaxis, figsize=[15, 7])

  # Set x, y labels of size 14 and title label of size 16.
  plt.xlabel(xlabel=xaxis, size=14)
  plt.ylabel(ylabel=yaxis, size=14)
  plt.title(label='Scatter Distribution of '+xaxis+' & '+yaxis, size=16)

  # Display the output
  plt.show()

# %%
new_links.head(5)
# Out:
#    Rank                    Title  ... Revenue (Millions) Metascore
# 0     1  Guardians of the Galaxy  ...             333.13      76.0
# 1     2               Prometheus  ...             126.46      65.0
# 2     3                    Split  ...             138.12      62.0
# 3     4                     Sing  ...             270.32      59.0
# 4     5            Suicide Squad  ...             325.02      40.0
#
# [5 rows x 12 columns]

# %%
plotScatterChart(data=new_links, xaxis='Rating', yaxis='Votes')

# %% [markdown]
# **Observations**
# 1.   Highest rating of 9 got 1.75 voates
# 2.   Rating below 2 got .25 votes overall
# 3.   Movies rating from 5 to 8 received max 0.75 votes
# 4.   List item

# %% [markdown]
# plotScatterChart(data=new_links, xaxis='star_rating', yaxis='duration',)

# %%
plt.hist(new_links['Year'])  # 10 bins by default
# Out:
# (array([ 41.,  44.,  48.,  45.,  57.,  57.,  62.,  84.,  93., 307.]),
#  array([2006., 2007., 2008., 2009., 2010., 2011., 2012., 2013., 2014.,
#         2015., 2016.]),
#  <a list of 10 Patch objects>)

# %%
new_links.head(5)
# Out:
#    Rank                    Title  ... Revenue (Millions) Metascore
# 0     1  Guardians of the Galaxy  ...             333.13      76.0
# 1     2               Prometheus  ...             126.46      65.0
# 2     3                    Split  ...             138.12      62.0
# 3     4                     Sing  ...             270.32      59.0
# 4     5            Suicide Squad  ...             325.02      40.0
#
# [5 rows x 12 columns]

# %% [markdown]
# Questions: Which movie has earned the maximum revenue in year 2016?

# %%
new_links.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
maximum_revenue = pd.DataFrame(new_links.groupby(by='Revenue (Millions)', as_index=False)['Revenue (Millions)'].sum().sort_values(by='Revenue (Millions)', ascending = False))
maximum_revenue.head()
# Out:
#      Revenue (Millions)
# 788              936.63
# 787              760.51
# 786              652.18
# 785              623.28
# 784              533.32

# %% [markdown]
# Which Rating movie has earned more revenues ?

# %%
groupby_rating = pd.DataFrame(new_links.groupby('Rating')['Revenue (Millions)'].nunique())
groupby_rating.head(100)
# Out:
#         Revenue (Millions)
# Rating
# 1.9                      1
# 2.7                      1
# 3.9                      2
# 4.0                      1
# 4.1                      1
# 4.3                      3
# 4.4                      1
# 4.6                      2
# 4.7                      3
# 4.8                      1
# 4.9                      6
# 5.0                      1
# 5.1                      5
# 5.2                      6
# 5.3                      8
# 5.4                     10
# 5.5                     11
# 5.6                     13
# 5.7                     15
# 5.8                     21
# 5.9                     15
# 6.0                     20
# 6.1                     22
# 6.2                     33
# 6.3                     36
# 6.4                     30
# 6.5                     35
# 6.6                     37
# 6.7                     42
# 6.8                     33
# 6.9                     23
# 7.0                     43
# 7.1                     40
# ...

# %%
groupby_rating.describe()
# Out:
#        Revenue (Millions)
# count           50.000000
# mean            16.720000
# std             14.291485
# min              1.000000
# 25%              3.000000
# 50%             14.000000
# 75%             29.750000
# max             43.000000

# %% [markdown]
# **Observations**
#
#
# 1.   On an average  every movie has earned 16.72 ratings

# %% [markdown]
# Questions Top 5  revenue movies of till Year 2016?

# %%
#total_revenue  = pd.DataFrame(new_links.groupby('Revenue (Millions)')['Year'].sum()
#actor_unique = pd.DataFrame(new_links.sort_values)
# five largest values in column age
#df.nlargest(5, ['Age'])
new_links.nlargest(5, ['Revenue (Millions)'])
#dx = pd.DataFrame(new_links.groupby('Metascore')['Votes']
# Out:
#     Rank  ... Metascore
# 50    51  ...      81.0
# 87    88  ...      83.0
# 85    86  ...      59.0
# 76    77  ...      69.0
# 54    55  ...      82.0
#
# [5 rows x 12 columns]

# %% [markdown]
# Questions Movies released in Year 2016?

# %%
new_links
# Out:
#      Rank                     Title  ... Revenue (Millions) Metascore
# 0       1   Guardians of the Galaxy  ...             333.13      76.0
# 1       2                Prometheus  ...             126.46      65.0
# 2       3                     Split  ...             138.12      62.0
# 3       4                      Sing  ...             270.32      59.0
# 4       5             Suicide Squad  ...             325.02      40.0
# ..    ...                       ...  ...                ...       ...
# 993   994  Resident Evil: Afterlife  ...              60.13      37.0
# 994   995                 Project X  ...              54.72      48.0
# 996   997           Hostel: Part II  ...              17.54      46.0
# 997   998    Step Up 2: The Streets  ...              58.01      50.0
# 999  1000                Nine Lives  ...              19.64      11.0
#
# [838 rows x 12 columns]

# %%
# filtering with query method
#new_links = new_links.query('Year == 2016', inplace = True)
#new_links.head(10)

# %%
new_links.head(10)
# Out:
#     Rank  ... Metascore
# 0      1  ...      76.0
# 1      2  ...      65.0
# 2      3  ...      62.0
# 3      4  ...      59.0
# 4      5  ...      40.0
# 5      6  ...      42.0
# 6      7  ...      93.0
# 8      9  ...      78.0
# 9     10  ...      41.0
# 10    11  ...      66.0
#
# [10 rows x 12 columns]

# %%
plt.hist(new_links['Rating'])
#plt.hist(new_links['Runtime'], bins=15, color='Red')           
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html
plt.xlabel("duration in mins.")
plt.ylabel("Count")
plt.title("Histogram of piece Runtime")
plt.show()

# %%
plt.plot(new_links['Metascore'])
plt.show()

# %%
new_links.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
groupby_rating = pd.DataFrame(new_links.groupby('Year')['Runtime (Minutes)'].nunique())
groupby_rating.head(100)
# Out:
#       Runtime (Minutes)
# Year
# 2006                 27
# 2007                 32
# 2008                 35
# 2009                 32
# 2010                 32
# 2011                 41
# 2012                 42
# 2013                 45
# 2014                 52
# 2015                 48
# 2016                 64

# %% [markdown]
# **Divide the dataframe**
#       ** 2000-2005**

# %%
links_2000_2005_genre1 = links.loc[(links.Year >= 2000) & (links.Year <= 2005) & \
                        ((links.Genre == 'Action') | (links.Genre == 'Adventure') | \
                       (links.Genre == 'Animation') | (links.Genre == 'Biography') | \
                       (links.Genre == 'Comedy') | (links.Genre == 'Crime'))]

# %%
links_2000_2005_genre2 = links.loc[(links.Year >= 2000) & (links.Year <= 2005) & \
                        ((links.Genre == 'Documentary') | (links.Genre == 'Drama') | \
                       (links.Genre == 'Family') | (links.Genre == 'Fantasy') | \
                       (links.Genre == 'Horror') | (links.Genre == 'Music'))]

# %%
links_2000_2005_genre3 = links.loc[(links.Year >= 2000) & (links.Year <= 2005) & \
                        ((links.Genre == 'Mystery') | (links.Genre == 'Romance') | \
                       (links.Genre == 'Sci') | (links.Genre == 'Thriller') | \
                       (links.Genre == 'War') | (links.Genre == 'Western'))]

# %% [markdown]
# **2006-2011**

# %%
# subsetting the dataframe
links_2006_2011_genre1 = links.loc[(links.Year >= 2006) & (links.Year <= 2011) & \
                        ((links.Genre == 'Action') | (links.Genre == 'Adventure') | \
                       (links.Genre == 'Animation') | (links.Genre == 'Biography') | \
                       (links.Genre == 'Comedy') | (links.Genre == 'Crime'))]

# %%
links_2006_2011_genre2 = links.loc[(links.Year >= 2006) & (links.Year <= 2011) & \
                        ((links.Genre == 'Documentary') | (links.Genre == 'Drama') | \
                       (links.Genre == 'Family') | (links.Genre == 'Fantasy') | \
                       (links.Genre == 'Horror') | (links.Genre == 'Music'))]

# %%
links_2006_2011_genre3 = links.loc[(links.Year >= 2006) & (links.Year <= 2011) & \
                        ((links.Genre == 'Mystery') | (links.Genre == 'Romance') | \
                       (links.Genre == 'Sci') | (links.Genre == 'Thriller') | \
                       (links.Genre == 'War') | (links.Genre == 'Western'))]

# %% [markdown]
# **2012-2017**

# %%
links_2012_2017_genre1 = links.loc[(links.Year >= 2012) & (links.Year <= 2017) & \
                        ((links.Genre == 'Action') | (links.Genre == 'Adventure') | \
                       (links.Genre == 'Animation') | (links.Genre == 'Biography') | \
                       (links.Genre == 'Comedy') | (links.Genre == 'Crime'))]

# %%
links_2012_2017_genre2 = links.loc[(links.Year >= 2012) & (links.Year <= 2017) & \
                        ((links.Genre == 'Documentary') | (links.Genre == 'Drama') | \
                       (links.Genre == 'Family') | (links.Genre == 'Fantasy') | \
                       (links.Genre == 'Horror') | (links.Genre == 'Music'))]

# %%
links_2012_2017_genre3 = links.loc[(links.Year >= 2012) & (links.Year <= 2017) & \
                        ((links.Genre == 'Mystery') | (links.Genre == 'Romance') | \
                       (links.Genre == 'Sci') | (links.Genre == 'Thriller') | \
                       (links.Genre == 'War') | (links.Genre == 'Western'))]

# %% [markdown]
# **Overview of a sub dataframe for 2012-2017**

# %%
links_2012_2017_genre2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 21 to 978
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                44 non-null     int64
#  1   Title               44 non-null     object
#  2   Genre               44 non-null     object
#  3   Description         44 non-null     object
#  4   Director            44 non-null     object
#  5   Actors              44 non-null     object
#  6   Year                44 non-null     int64
#  7   Runtime (Minutes)   44 non-null     int64
#  8   Rating              44 non-null     float64
#  9   Votes               44 non-null     int64
#  10  Revenue (Millions)  25 non-null     float64
#  11  Metascore           39 non-null     float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 4.5+ KB

# %% [markdown]
# To sum up, here are the data that I use:
#
# Movie title -> Movie
#
# *   Genre of the movie -> Genre
# *   Movie duration (in minutes) -> timeMin
# *   Release year of the film -> Year
# *   Number of public votes -> Vote
# *   Public rating (score out of 10) -> audienceRating
# *  Critics rating (score out of 100) -> criticRating
# *   Movie Gross (in millions of dollars) -> grossMillions

# %% [markdown]
# **Visualization of data**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
links.Director = links.Director.astype('category')
links.Genre = links.Genre.astype('category')
links.Year = links.Year.astype('int64')
#links.Revenue = links.Revenue.astype('float64 ')

# %%
links.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   category
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   category
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: category(2), float64(3), int64(4), object(3)
# memory usage: 118.8+ KB

# %%
links.Genre.cat.categories
# Out:
# Index(['Action', 'Action,Adventure', 'Action,Adventure,Biography',
#        'Action,Adventure,Comedy', 'Action,Adventure,Crime',
#        'Action,Adventure,Drama', 'Action,Adventure,Family',
#        'Action,Adventure,Fantasy', 'Action,Adventure,Horror',
#        'Action,Adventure,Mystery',
#        ...
#        'Mystery,Romance,Thriller', 'Mystery,Sci-Fi,Thriller',
#        'Mystery,Thriller', 'Mystery,Thriller,Western', 'Romance,Sci-Fi',
#        'Romance,Sci-Fi,Thriller', 'Sci-Fi', 'Sci-Fi,Thriller', 'Thriller',
#        'Thriller,War'],
#       dtype='object', length=207)

# %% [markdown]
# **Joinplots**
#
#
# **Graphical representation of  Yearwise  Ranking

# %%
j1 = sns.jointplot(data=links, x='Rank', y='Year')

# %% [markdown]
# **Joinplot with hexagonal**
#
# **Hexagon representation of YearWise Rank**

# %%
k1 = sns.jointplot(data=links, x='Year', y='Rank', kind='hex')

# %% [markdown]
# **The most popular movies based on Ratings between 2000 and 2017**

# %% [markdown]
# **Graphical representation of  Revenue as per ratings **

# %%
j2 = sns.jointplot(data=links, y='Revenue (Millions)', x='Rating')

# %% [markdown]
# **Graphical representation for year wise rank of the movies **

# %%
j3 = sns.jointplot(data=links, y='Year', x='Rank')

# %% [markdown]
# **Graphical representation of the gross of the films according to the notes of the public between 2000 and 2017**

# %%
j4 = sns.jointplot(data=links, y='Revenue (Millions)', x='Metascore')

# %% [markdown]
# **Distribution by ratings, duration, revenue, votes and year**

# %%
fig, axes = plt.subplots(2, 3)
fig.set_size_inches(12, 8)

m1 = sns.distplot(links.Rating, bins=15, ax=axes[0, 0])
#m2 = sns.distplot(new_links.columns.Revenue, bins=15, ax=axes[0, 1])
#m3 = sns.distplot(links.Duration(Minutes), bins=15, ax=axes[0, 2])
m4 = sns.distplot(links.Metascore, bins=15, ax=axes[1, 0])
m5 = sns.distplot(links.Votes, bins=15, ax=axes[1, 1])
m6 = sns.distplot(links.Year, bins=15, ax=axes[1, 2])

#plt.setp(axes, yticks=[])
plt.tight_layout()

# %% [markdown]
# **Histograms of movies by genre between 2000 and 2017**

# %% [markdown]
# **Preparing data for histograms**
#
# **Genre1 2000-2017 **

# %%
# subsetting the dataframe
links_2000_2017_genre1 = links.loc[(links.Genre == 'Action') | (links.Genre == 'Adventure') | \
                       (links.Genre == 'Animation') | (links.Genre == 'Biography') | \
                       (links.Genre == 'Comedy') | (links.Genre == 'Crime')]

# %%
links_2000_2017_genre1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 7 to 994
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                35 non-null     int64
#  1   Title               35 non-null     object
#  2   Genre               35 non-null     category
#  3   Description         35 non-null     object
#  4   Director            35 non-null     category
#  5   Actors              35 non-null     object
#  6   Year                35 non-null     int64
#  7   Runtime (Minutes)   35 non-null     int64
#  8   Rating              35 non-null     float64
#  9   Votes               35 non-null     int64
#  10  Revenue (Millions)  28 non-null     float64
#  11  Metascore           32 non-null     float64
# dtypes: category(2), float64(3), int64(4), object(3)
# memory usage: 39.8+ KB

# %%
links_2000_2017_genre1.Genre.cat.categories
# Out:
# Index(['Action', 'Action,Adventure', 'Action,Adventure,Biography',
#        'Action,Adventure,Comedy', 'Action,Adventure,Crime',
#        'Action,Adventure,Drama', 'Action,Adventure,Family',
#        'Action,Adventure,Fantasy', 'Action,Adventure,Horror',
#        'Action,Adventure,Mystery',
#        ...
#        'Mystery,Romance,Thriller', 'Mystery,Sci-Fi,Thriller',
#        'Mystery,Thriller', 'Mystery,Thriller,Western', 'Romance,Sci-Fi',
#        'Romance,Sci-Fi,Thriller', 'Sci-Fi', 'Sci-Fi,Thriller', 'Thriller',
#        'Thriller,War'],
#       dtype='object', length=207)

# %%
links_2000_2017_genre1.Genre = links_2000_2017_genre1.Genre.cat.remove_unused_categories()

# %%
links_2000_2017_genre1.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy'], dtype='object')

# %%
links_2000_2017_genre1.head()
# Out:
#      Rank            Title   Genre  ...  Votes Revenue (Millions) Metascore
# 7       8         Mindhorn  Comedy  ...   2490                NaN      71.0
# 25     26  Paris pieds nus  Comedy  ...    222                NaN       NaN
# 28     29         Bad Moms  Comedy  ...  66540             113.08      60.0
# 30     31         Why Him?  Comedy  ...  48123              60.31      39.0
# 106   107     The Comedian  Comedy  ...   1954               1.66      40.0
#
# [5 rows x 12 columns]

# %% [markdown]
# **Genre2 2000-2017**

# %%
links_2000_2017_genre2 = links.loc[(links.Genre == 'Documentary') | (links.Genre == 'Drama') | \
                       (links.Genre == 'Family') | (links.Genre == 'Fantasy') | \
                       (links.Genre == 'Horror') | (links.Genre == 'Music')]

# %%
links_2000_2017_genre2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59 entries, 21 to 996
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                59 non-null     int64
#  1   Title               59 non-null     object
#  2   Genre               59 non-null     category
#  3   Description         59 non-null     object
#  4   Director            59 non-null     category
#  5   Actors              59 non-null     object
#  6   Year                59 non-null     int64
#  7   Runtime (Minutes)   59 non-null     int64
#  8   Rating              59 non-null     float64
#  9   Votes               59 non-null     int64
#  10  Revenue (Millions)  38 non-null     float64
#  11  Metascore           52 non-null     float64
# dtypes: category(2), float64(3), int64(4), object(3)
# memory usage: 41.9+ KB

# %%
links_2000_2017_genre2.Genre.cat.categories
# Out:
# Index(['Action', 'Action,Adventure', 'Action,Adventure,Biography',
#        'Action,Adventure,Comedy', 'Action,Adventure,Crime',
#        'Action,Adventure,Drama', 'Action,Adventure,Family',
#        'Action,Adventure,Fantasy', 'Action,Adventure,Horror',
#        'Action,Adventure,Mystery',
#        ...
#        'Mystery,Romance,Thriller', 'Mystery,Sci-Fi,Thriller',
#        'Mystery,Thriller', 'Mystery,Thriller,Western', 'Romance,Sci-Fi',
#        'Romance,Sci-Fi,Thriller', 'Sci-Fi', 'Sci-Fi,Thriller', 'Thriller',
#        'Thriller,War'],
#       dtype='object', length=207)

# %%
#on supprime toutes les categories non utilises
links_2000_2017_genre2.Genre = links_2000_2017_genre2.Genre.cat.remove_unused_categories()

links_2000_2017_genre2.Genre.cat.categories
# Out:
# Index(['Drama', 'Horror'], dtype='object')

# %%
links_2000_2017_genre2.head()
# Out:
#     Rank                    Title  ... Revenue (Millions) Metascore
# 21    22    Manchester by the Sea  ...              47.70      96.0
# 41    42                Moonlight  ...              27.85      99.0
# 42    43  Don't Fuck in the Woods  ...                NaN       NaN
# 44    45                Lowriders  ...               4.21      57.0
# 49    50            The Last Face  ...                NaN      16.0
#
# [5 rows x 12 columns]

# %% [markdown]
# **Genre3 2000-2017**

# %%
links_2000_2017_genre3 = links.loc[(links.Genre == 'Mystery') | (links.Genre == 'Romance') | \
                       (links.Genre == 'Sci') | (links.Genre == 'Thriller') | \
                       (links.Genre == 'War') | (links.Genre == 'Western')]

# %%
links_2000_2017_genre3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 282 to 942
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                9 non-null      int64
#  1   Title               9 non-null      object
#  2   Genre               9 non-null      category
#  3   Description         9 non-null      object
#  4   Director            9 non-null      category
#  5   Actors              9 non-null      object
#  6   Year                9 non-null      int64
#  7   Runtime (Minutes)   9 non-null      int64
#  8   Rating              9 non-null      float64
#  9   Votes               9 non-null      int64
#  10  Revenue (Millions)  1 non-null      float64
#  11  Metascore           7 non-null      float64
# dtypes: category(2), float64(3), int64(4), object(3)
# memory usage: 37.5+ KB

# %%
links_2000_2017_genre3.Genre.cat.categories
# Out:
# Index(['Action', 'Action,Adventure', 'Action,Adventure,Biography',
#        'Action,Adventure,Comedy', 'Action,Adventure,Crime',
#        'Action,Adventure,Drama', 'Action,Adventure,Family',
#        'Action,Adventure,Fantasy', 'Action,Adventure,Horror',
#        'Action,Adventure,Mystery',
#        ...
#        'Mystery,Romance,Thriller', 'Mystery,Sci-Fi,Thriller',
#        'Mystery,Thriller', 'Mystery,Thriller,Western', 'Romance,Sci-Fi',
#        'Romance,Sci-Fi,Thriller', 'Sci-Fi', 'Sci-Fi,Thriller', 'Thriller',
#        'Thriller,War'],
#       dtype='object', length=207)

# %%
#on supprime toutes les categories non utilises
links_2000_2017_genre3.Genre = links_2000_2017_genre3.Genre.cat.remove_unused_categories()

links_2000_2017_genre3.Genre.cat.categories
# Out:
# Index(['Thriller'], dtype='object')

# %%
links_2000_2017_genre3.head()
# Out:
#      Rank               Title     Genre  ...   Votes Revenue (Millions) Metascore
# 282   283         Death Proof  Thriller  ...  220236                NaN       NaN
# 289   290                Iris  Thriller  ...     726                NaN       NaN
# 444   445        The Thinning  Thriller  ...    4531                NaN      31.0
# 729   730           The Guest  Thriller  ...   71069               0.32      76.0
# 746   747  Only for One Night  Thriller  ...     313                NaN      60.0
#
# [5 rows x 12 columns]

# %% [markdown]
# **Visualization of histograms of movies by genre between 2000 and 2017**

# %% [markdown]
# **Histogram of the gross by genre of movie between 2000 and 2017**

# %%
sns.set()

#2000-2017
grossByGenre_2000_2017_genre1 = list()
grossByGenre_2000_2017_genre2 = list()
grossByGenre_2000_2017_genre3 = list()

labels_2000_2017_genre1 = list()
labels_2000_2017_genre2 = list()
labels_2000_2017_genre3 = list()

# %%
#2000-2017
#2000-2017 genre1
for dataGenre_2000_2017_genre1 in links_2000_2017_genre1.Genre.cat.categories[0:6]:
    grossByGenre_2000_2017_genre1.append(links_2000_2017_genre1[links_2000_2017_genre1.Genre == \
                                                              dataGenre_2000_2017_genre1].Votes)
    labels_2000_2017_genre1.append(dataGenre_2000_2017_genre1)

# %%
#2000-2017 genre2
for dataGenre_2000_2017_genre2 in links_2000_2017_genre2.Genre.cat.categories[0:6]:
    grossByGenre_2000_2017_genre2.append(links_2000_2017_genre2[links_2000_2017_genre2.Genre == \
                                                                     dataGenre_2000_2017_genre2].Votes)
    labels_2000_2017_genre2.append(dataGenre_2000_2017_genre2)

# %%
#2000-2017 genre3
for dataGenre_2000_2017_genre3 in links_2000_2017_genre3.Genre.cat.categories[0:6]:
    grossByGenre_2000_2017_genre3.append(links_2000_2017_genre3[links_2000_2017_genre3.Genre == \
                                                                     dataGenre_2000_2017_genre3].Votes)
    labels_2000_2017_genre3.append(dataGenre_2000_2017_genre3)

# %%
# 3 lines, 3 columns
fig, ax = plt.subplots(1,3)
fig.set_size_inches(15, 3) #size of A4 paper 
#2000-2017
ax[0].hist(grossByGenre_2000_2017_genre1, bins=30, stacked=True, rwidth=1, label=labels_2000_2017_genre1)
ax[1].hist(grossByGenre_2000_2017_genre2, bins=30, stacked=True, rwidth=1, label=labels_2000_2017_genre2)
ax[2].hist(grossByGenre_2000_2017_genre3, bins=30, stacked=True, rwidth=1, label=labels_2000_2017_genre3)

ax[0].set(xlabel='GrossMillions 2000-2017', ylabel='Number of movies')
ax[1].set(xlabel='GrossMillions 2000-2017')
ax[2].set(xlabel='GrossMillions 2000-2017')

plt.suptitle('Movie Gross Distribution: 2000-2017')
for i in range(3):
    ax[i].legend()

plt.show()

# %% [markdown]
# **Histogram of audience ratings by genre of movie between 2000 and 2017**

# %%
sns.set()

#2000-2017
grossByGenre_2000_2017_genre1 = list()
grossByGenre_2000_2017_genre2 = list()
grossByGenre_2000_2017_genre3 = list()

labels_2000_2017_genre1 = list()
labels_2000_2017_genre2 = list()
labels_2000_2017_genre3 = list()

# %%
#2000-2017
#2000-2017 genre1
for dataGenre_2000_2017_genre1 in links_2000_2017_genre1.Genre.cat.categories[0:6]:
    grossByGenre_2000_2017_genre1.append(links_2000_2017_genre1[links_2000_2017_genre1.Genre == \
                                                                     dataGenre_2000_2017_genre1].Rating)
    labels_2000_2017_genre1.append(dataGenre_2000_2017_genre1)

# %%
#2000-2017 genre2
for dataGenre_2000_2017_genre2 in links_2000_2017_genre2.Genre.cat.categories[0:6]:
    grossByGenre_2000_2017_genre2.append(links_2000_2017_genre2[links_2000_2017_genre2.Genre == \
                                                                     dataGenre_2000_2017_genre2].Rating)
    labels_2000_2017_genre2.append(dataGenre_2000_2017_genre2)

# %%
#2000-2017 genre3
for dataGenre_2000_2017_genre3 in links_2000_2017_genre3.Genre.cat.categories[0:6]:
    grossByGenre_2000_2017_genre3.append(links_2000_2017_genre3[links_2000_2017_genre3.Genre == \
                                                                     dataGenre_2000_2017_genre3].Rating)
    labels_2000_2017_genre3.append(dataGenre_2000_2017_genre3)

# %%
# 3 lines, 3 columns
fig, ax = plt.subplots(1,3)
fig.set_size_inches(15, 3) #size of A4 paper   

#2000-2017
ax[0].hist(grossByGenre_2000_2017_genre1, bins=30, stacked=True, rwidth=1, label=labels_2000_2017_genre1)
ax[1].hist(grossByGenre_2000_2017_genre2, bins=30, stacked=True, rwidth=1, label=labels_2000_2017_genre2)
ax[2].hist(grossByGenre_2000_2017_genre3, bins=30, stacked=True, rwidth=1, label=labels_2000_2017_genre3)

ax[0].set(xlabel='audienceRating 2000-2017', ylabel='Number of movies')
ax[1].set(xlabel='audienceRating 2000-2017')
ax[2].set(xlabel='audienceRating 2000-2017')

plt.suptitle('Movie audienceRating Distribution: 2000-2017')
for i in range(3):
    ax[i].legend()

plt.show()

# %% [markdown]
# **Histogram of votes by genre of movie between 2000 and 2017**

# %%
links_2000_2017_genre1.Year = links_2000_2017_genre1.Year.astype('int64')
links_2000_2017_genre1.Year = links_2000_2017_genre1.Year.astype('int64')
links_2000_2017_genre1.Year = links_2000_2017_genre1.Year.astype('int64')

sns.set()

#2000-2017
grossByGenre_2000_2017_genre1 = list()
grossByGenre_2000_2017_genre2 = list()
grossByGenre_2000_2017_genre3 = list()

labels_2000_2017_genre1 = list()
labels_2000_2017_genre2 = list()
labels_2000_2017_genre3 = list()

# %%
#2000-2017
#2000-2017 genre1
for dataGenre_2000_2017_genre1 in links_2000_2017_genre1.Genre.cat.categories[0:6]:
    grossByGenre_2000_2017_genre1.append(links_2000_2017_genre1[links_2000_2017_genre1.Genre == \
                                                                     dataGenre_2000_2017_genre1].Votes)
    labels_2000_2017_genre1.append(dataGenre_2000_2017_genre1)

# %%
#2000-2017 genre2
for dataGenre_2000_2017_genre2 in links_2000_2017_genre2.Genre.cat.categories[0:6]:
    grossByGenre_2000_2017_genre2.append(links_2000_2017_genre2[links_2000_2017_genre2.Genre == \
                                                                     dataGenre_2000_2017_genre2].Votes)
    labels_2000_2017_genre2.append(dataGenre_2000_2017_genre2)

# %%
#2000-2017 genre3
for dataGenre_2000_2017_genre3 in links_2000_2017_genre3.Genre.cat.categories[0:6]:
    grossByGenre_2000_2017_genre3.append(links_2000_2017_genre3[links_2000_2017_genre3.Genre == \
                                                                     dataGenre_2000_2017_genre3].Votes)
    labels_2000_2017_genre3.append(dataGenre_2000_2017_genre3)

# %%
# 3 lines, 3 columns
fig, ax = plt.subplots(1,3)
fig.set_size_inches(15, 3) #size of A4 paper   

#2000-2017
ax[0].hist(grossByGenre_2000_2017_genre1, bins=30, stacked=True, rwidth=1, label=labels_2000_2017_genre1)
ax[1].hist(grossByGenre_2000_2017_genre2, bins=30, stacked=True, rwidth=1, label=labels_2000_2017_genre2)
ax[2].hist(grossByGenre_2000_2017_genre3, bins=30, stacked=True, rwidth=1, label=labels_2000_2017_genre3)

ax[0].set(xlabel='Vote 2000-2017', ylabel='Number of movies')
ax[1].set(xlabel='Vote 2000-2017')
ax[2].set(xlabel='Vote 2000-2017')

plt.suptitle('Movie Vote Distribution: 2000-2017')
for i in range(3):
    ax[i].legend()

plt.show()

# %% [markdown]
# # **KDE Plot kernel density estimate**

# %% [markdown]
# **Graphical representation of  ratings based  genre of film between 2000 and 2017**

# %%
vis1 = sns.lmplot(data=links_2000_2017_genre1, x='Rating', y='Votes', \
                 fit_reg=False, hue='Genre', size=6, aspect=1)

# %%
vis2 = sns.lmplot(data=links_2000_2017_genre2, x='Rating', y='Votes', \
                 fit_reg=False, hue='Genre', size=6, aspect=1)

# %%
vis3 = sns.lmplot(data=links_2000_2017_genre3, x='Rating', y='Votes', \
                 fit_reg=False, hue='Genre', size=6, aspect=1)

# %% [markdown]
# # **boxplot and violinplot**

# %% [markdown]
# **Boxplot of some data depending on the genres of movies between 2000 and 2017**

# %%
links_2000_2017_genre1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 7 to 994
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                35 non-null     int64
#  1   Title               35 non-null     object
#  2   Genre               35 non-null     category
#  3   Description         35 non-null     object
#  4   Director            35 non-null     category
#  5   Actors              35 non-null     object
#  6   Year                35 non-null     int64
#  7   Runtime (Minutes)   35 non-null     int64
#  8   Rating              35 non-null     float64
#  9   Votes               35 non-null     int64
#  10  Revenue (Millions)  28 non-null     float64
#  11  Metascore           32 non-null     float64
# dtypes: category(2), float64(3), int64(4), object(3)
# memory usage: 29.5+ KB

# %%
fig, axes = plt.subplots(2, 2)
fig.set_size_inches(11.7, 5.27)
plt.subplots_adjust(wspace=0.2, hspace=0.4)

sns.boxplot(data=links_2000_2017_genre1, x='Genre', y='Rating', ax=axes[0, 0])
sns.boxplot(data=links_2000_2017_genre1, x='Genre', y='Votes', ax=axes[0, 1])
sns.boxplot(data=links_2000_2017_genre1, x='Genre', y='Metascore', ax=axes[1, 0])
sns.boxplot(data=links_2000_2017_genre1, x='Genre', y='Runtime (Minutes)', ax=axes[1, 1])

plt.suptitle('Some data according to their genre: 2000-2017')

plt.show()

# %%
sns.set()
fig, axes = plt.subplots(2, 2)
fig.set_size_inches(11.7, 5.27)
plt.subplots_adjust(wspace=0.2, hspace=0.4)

sns.boxplot(data=links_2000_2017_genre2, x='Genre', y='Rating', ax=axes[0, 0])
sns.boxplot(data=links_2000_2017_genre2, x='Genre', y='Votes', ax=axes[0, 1])
sns.boxplot(data=links_2000_2017_genre2, x='Genre', y='Revenue (Millions)', ax=axes[1, 0])
sns.boxplot(data=links_2000_2017_genre2, x='Genre', y='Runtime (Minutes)', ax=axes[1, 1])

plt.suptitle('Some data according to their genre: 2000-2017')
plt.show()

# %%
fig, axes = plt.subplots(2, 2)
fig.set_size_inches(11.7, 5.27)
plt.subplots_adjust(wspace=0.2, hspace=0.4)

sns.boxplot(data=links_2000_2017_genre3, x='Genre', y='Rating', ax=axes[0, 0])
sns.boxplot(data=links_2000_2017_genre3, x='Genre', y='Votes', ax=axes[0, 1])
sns.boxplot(data=links_2000_2017_genre3, x='Genre', y='Revenue (Millions)', ax=axes[1, 0])
sns.boxplot(data=links_2000_2017_genre3, x='Genre', y='Runtime (Minutes)', ax=axes[1, 1])

plt.suptitle('Some data according to their genre: 2000-2017')
plt.show()

# %% [markdown]
# # **violinpolot**

# %%
fig, axes = plt.subplots(2, 2)
fig.set_size_inches(11.7, 5.27)
plt.subplots_adjust(wspace=0.2, hspace=0.4)

sns.violinplot(data=links_2000_2017_genre1, x='Genre', y='Rating', ax=axes[0, 0])
sns.violinplot(data=links_2000_2017_genre1, x='Genre', y='Votes', ax=axes[0, 1])
sns.violinplot(data=links_2000_2017_genre1, x='Genre', y='Revenue (Millions)', ax=axes[1, 0])
sns.violinplot(data=links_2000_2017_genre1, x='Genre', y='Runtime (Minutes)', ax=axes[1, 1])

plt.suptitle('Some data according to their genre: 2000-2017')
plt.show()

# %%
fig, axes = plt.subplots(2, 2)
fig.set_size_inches(11.7, 5.27)
plt.subplots_adjust(wspace=0.2, hspace=0.4)

sns.violinplot(data=links_2000_2017_genre2, x='Genre', y='Rating', ax=axes[0, 0])
sns.violinplot(data=links_2000_2017_genre2, x='Genre', y='Votes', ax=axes[0, 1])
sns.violinplot(data=links_2000_2017_genre2, x='Genre', y='Revenue (Millions)', ax=axes[1, 0])
sns.violinplot(data=links_2000_2017_genre2, x='Genre', y='Runtime (Minutes)', ax=axes[1, 1])

plt.suptitle('Some data according to their genre: 2000-2017')
plt.show()

# %%
fig, axes = plt.subplots(2, 2)
fig.set_size_inches(11.7, 5.27)
plt.subplots_adjust(wspace=0.2, hspace=0.4)

sns.violinplot(data=links_2000_2017_genre3, x='Genre', y='Rating', ax=axes[0, 0])
sns.violinplot(data=links_2000_2017_genre3, x='Genre', y='Votes', ax=axes[0, 1])
sns.violinplot(data=links_2000_2017_genre3, x='Genre', y='Revenue (Millions)', ax=axes[1, 0])
sns.violinplot(data=links_2000_2017_genre3, x='Genre', y='Runtime (Minutes)', ax=axes[1, 1])

plt.suptitle('Some data according to their genre: 2000-2017')
plt.show()

# %% [markdown]
# Conclusion
# The preparation of the data, the modeling of these data, then the visualization of these data with a wide variety of graphs, and finally the interpretation of these graphs made it possible to conduct an analysis and a global view of movies released in the cinema between 2000 and 2017.
#
# This study through a large volume of data, allowed me to determine the following points for movies between 2000 and 2017:
#
# Audience ratings of the movies are quite close to those of the critics ratings
# Critics rate more severely than the public
# Most movies last between 60 minutes and 120 minutes
# Movies that are well rated by public and critics make the most money
# The more the public appreciates a film, the more they vote and give a good rating
# Movies between 60 minutes and 150 minutes (2h30) make the most money
# Movies that exceed 3 hours bring in the least money
# Animation, biography, crime, drama, mystery and sci-fi movies are the highest rated by critics
# Animation, adventure, biography, crime, documentary, mystery and science-fiction movies are the highest rated by the public
# Action, adventure, animation and family movies are the ones that made the most money
# Action, adventure, biography, crime, family, drama and mystery movies are the ones that last the longest in terms of duration
# Biography, comedy, crime, drama and horror movies were the most numerous
# There were few mystery, western or war movies
# Movies that made the most money are action, drama and mystery movies
